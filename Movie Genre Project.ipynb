# %% [markdown]
# # **Movie Genre Data Analysis**

# %% [markdown]
# ## **Introduction**
# We are going to focus highly on genre's. I want to know everything about Genre's.
#
# Here are some things I want to look at:
# ### **Research Questions (Q):**
#
# 1. Which genres are the most commmon (number of movies made)?
# 2. Which genres have high avg budget and revenue?
# 3. Which genres have high avg profit?
# 4. Which genres have high avg popularity?
# 5. Which genres have highest number of movies with a voting avg >=8?
#
# ### **Research Hypotheses (H):**
#
# 1. The best movies according to vote avg return high profit and revenue.
# 2. The best movies according to popularity return high profit and revenue.
# 3. Highly budgeted movies return high profit.
# 4. Highly budgeted movies have a high popularity.

# %%
import pandas as pd
from pandas import Series, DataFrame
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read the data into a data frame
movies = pd.read_csv(r"D:\data analysis\pandas\inpedth\imdb_movies.csv")
movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
#lets check for duplicated
movies[movies.duplicated()]
# Out:
#          id    imdb_id  popularity    budget  revenue original_title  \
# 2090  42194  tt0411951     0.59643  30000000   967000         TEKKEN
#
#                                                    cast homepage  \
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline  ...  \
# 2090  Dwight H. Little  Survival is no game  ...
#
#                                                overview runtime  \
# 2090  In the year of 2039, after World Wars destroy ...      92
#
#                                            genres    production_companies  \
# 2090  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
#
#      release_date vote_count  vote_average  release_year  budget_adj  \
# 2090      3/20/10        110           5.0          2010  30000000.0
#
#       revenue_adj
# 2090     967000.0
#
# [1 rows x 21 columns]

# %%
#we saw that we have 1 row that is duplicate so lets remove her
movies.drop_duplicates(inplace = True)

# %%
movies[movies.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, imdb_id, popularity, budget, revenue, original_title, cast, homepage, director, tagline, keywords, overview, runtime, genres, production_companies, release_date, vote_count, vote_average, release_year, budget_adj, revenue_adj]
# Index: []
#
# [0 rows x 21 columns]

# %%
#we need to populate the genre column so we can answer our questions
movies['genres'].isnull().sum()
# Out:
# 23

# %%
#we can see we have 23 null values in the genre column
#we will remove that null values because it will mess with our data and our questions
movies.dropna(subset = ['genres'], inplace = True)

# %%
movies['genres'].isnull().sum() #checking if there is no null anymore
# Out:
# 0

# %%
#lets add a column off profit
movies['profit'] = movies['revenue'] - movies['budget']

# %%
movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
#now lets drop some columns we dont need for what we want to check.
column_to_keep = ['popularity','budget','revenue','original_title','runtime','genres','release_year','vote_count','vote_average','profit']
movies_genres = movies[column_to_keep]

# %%
#lets split the genre column up
split = movies_genres['genres'].str.split('|').apply(Series,1).stack() #split the genres and then convert them into a panda series and then stack everything 
split.index = split.index.droplevel(-1) #drops the inner most index level
split
# Out:
# C:\Users\The Eye\AppData\Local\Temp\ipykernel_22320\3510846568.py:2: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   split = movies_genres['genres'].str.split('|').apply(Series,1).stack() #split the genres and then convert them into a panda series and then stack everything
# 0                 Action
# 0              Adventure
# 0        Science Fiction
# 0               Thriller
# 1                 Action
#               ...
# 10863            Mystery
# 10863             Comedy
# 10864             Action
# 10864             Comedy
# 10865             Horror
# Length: 26955, dtype: object

# %%
#for the sake of memory we will delete the genre column and replace it by our new one
split.name = 'genres_split'
del movies_genres['genres']
movies_genres = movies_genres.join(split)

# %%
movies_genres.head()
# Out:
#    popularity     budget     revenue      original_title  runtime  \
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 1   28.419936  150000000   378436354  Mad Max: Fury Road      120
#
#    release_year  vote_count  vote_average      profit     genres_split
# 0          2015        5562           6.5  1363528810           Action
# 0          2015        5562           6.5  1363528810        Adventure
# 0          2015        5562           6.5  1363528810  Science Fiction
# 0          2015        5562           6.5  1363528810         Thriller
# 1          2015        6185           7.1   228436354           Action

# %% [markdown]
# 1. Which genres are the most commmon (number of movies made)?

# %%
genres_count = movies_genres.groupby('genres_split')[['original_title']].nunique().sort_values(by ='original_title')

# %%
genres_count
# Out:
#                  original_title
# genres_split
# Western                     163
# TV Movie                    167
# Foreign                     188
# War                         269
# History                     331
# Music                       403
# Documentary                 520
# Animation                   697
# Mystery                     796
# Fantasy                     899
# Science Fiction            1207
# Family                     1211
# Crime                      1337
# Adventure                  1442
# Horror                     1580
# Romance                    1686
# Action                     2339
# Thriller                   2841
# Comedy                     3750
# Drama                      4672

# %%
#lets visualize it
genres_count['original_title'].plot.pie(title = 'Movies Per Genre in %',autopct = '%1.1f%%',figsize = (10,10))
# Out:
# <Axes: title={'center': 'Movies Per Genre in %'}, ylabel='original_title'>

# %%
genres_count['original_title'].plot.barh(title = 'Movies Per Genre' , color = 'DarkBlue',figsize = (10,9))
# Out:
# <Axes: title={'center': 'Movies Per Genre'}, ylabel='genres_split'>

# %% [markdown]
# 2. Which genres have high avg budget and revenue?

# %%
genres_avg = movies_genres.groupby('genres_split').mean(numeric_only = True) #find avg per genres
pd.options.display.float_format = '{:2f}'.format #change the column that are in scientific notation to float

genres_avg
# Out:
#                  popularity          budget          revenue    runtime  \
# genres_split
# Action             0.926274 27727820.331376  72794732.002517 104.917785
# Adventure          1.154259 37543694.530931 113137861.069341 106.173351
# Animation          0.852182 23159781.606581  75256062.223176  68.181688
# Comedy             0.592607 13297915.618244  37526242.072238  96.745057
# Crime              0.744930 17663801.124815  42368661.645495 106.917282
# Documentary        0.181432   577149.148077   2041106.994231 102.651923
# Drama              0.591495 11880717.773529  29232255.725840 110.478151
# Family             0.786668 23359337.420796  72433176.373680  89.603574
# Fantasy            0.992840 32612585.348253  96313657.081878 100.736900
# Foreign            0.191496  1451434.925532   1520459.835106 107.228723
# History            0.575936 18594919.302395  32011793.215569 136.206587
# Horror             0.465357  6226529.210751  16822808.624313  94.424557
# ...

# %%
genres_avg.sort_values('budget', inplace = True) #sort and save to genres_avg

# %%
#plot 
genres_avg[['budget','revenue']].plot.barh(title = 'Budget and Revenue by Genre' , color = ('DarkBlue','c'),figsize = (10,9))
# Out:
# <Axes: title={'center': 'Budget and Revenue by Genre'}, ylabel='genres_split'>

# %%
genres_avg.sort_values('revenue', inplace = True)

# %%
genres_avg[['budget','revenue']].plot.barh(title = 'Budget and Revenue by Genre' , color = ('DarkBlue','c'),figsize = (10,9))
# Out:
# <Axes: title={'center': 'Budget and Revenue by Genre'}, ylabel='genres_split'>

# %% [markdown]
# 3. Which genres have high avg profit?

# %%
genres_avg
# Out:
#                  popularity          budget          revenue    runtime  \
# genres_split
# TV Movie           0.270896   267664.670659    251497.005988  91.982036
# Foreign            0.191496  1451434.925532   1520459.835106 107.228723
# Documentary        0.181432   577149.148077   2041106.994231 102.651923
# Horror             0.465357  6226529.210751  16822808.624313  94.424557
# Western            0.590615 18974107.975758  28568709.284848 117.575758
# Music              0.487321  9438627.549020  28571768.691176 105.137255
# Drama              0.591495 11880717.773529  29232255.725840 110.478151
# History            0.575936 18594919.302395  32011793.215569 136.206587
# Romance            0.592082 12531271.847547  35691972.327103 106.891355
# Comedy             0.592607 13297915.618244  37526242.072238  96.745057
# Mystery            0.690012 16119270.062963  40217566.661728 105.928395
# Thriller           0.741563 17207693.769178  41728417.543860 103.247678
# ...

# %%
genres_avg.sort_values('profit', inplace = True)

# %%
genres_avg['profit'].plot.barh(title = 'Profit by Genre' , color = 'DarkBlue',figsize = (10,9))
# Out:
# <Axes: title={'center': 'Profit by Genre'}, ylabel='genres_split'>

# %% [markdown]
# 4. Which genres have high avg popularity?

# %%
genres_avg.sort_values('popularity', inplace = True)

# %%
genres_avg['popularity'].plot.barh(title = 'Popularity by Genre' , color = 'DarkBlue',figsize = (10,9))
# Out:
# <Axes: title={'center': 'Popularity by Genre'}, ylabel='genres_split'>

# %% [markdown]
# 5. Which genres have highest number of movies with a voting avg >=8?

# %%
movies_genres.head()
# Out:
#    popularity     budget     revenue      original_title  runtime  \
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 1   28.419936  150000000   378436354  Mad Max: Fury Road      120
#
#    release_year  vote_count  vote_average      profit     genres_split
# 0          2015        5562      6.500000  1363528810           Action
# 0          2015        5562      6.500000  1363528810        Adventure
# 0          2015        5562      6.500000  1363528810  Science Fiction
# 0          2015        5562      6.500000  1363528810         Thriller
# 1          2015        6185      7.100000   228436354           Action

# %%
#to answer question 5 we first will filter on the vote count (becuase if its too low we cant really say much about the voting)
vote_fifty = movies_genres[(movies_genres['vote_count'] >= 50) & (movies_genres['vote_average'] >= 8)]
vote_zero = movies_genres[movies_genres['vote_average'] >= 8] #for good measure

# %%
genres_vote = vote_fifty.groupby('genres_split')[['original_title']].nunique().sort_values('original_title',ascending = True)

# %%
genres_vote['original_title'].plot.barh(title = 'Vote Average by Genre number of votes >= 50' , color = 'DarkBlue',figsize = (10,9))
# Out:
# <Axes: title={'center': 'Vote Average by Genre number of votes >= 50'}, ylabel='genres_split'>

# %%
genres_vote = vote_zero.groupby('genres_split')[['original_title']].nunique().sort_values('original_title',ascending = True)

# %%
genres_vote['original_title'].plot.barh(title = 'Vote Average by Genre' , color = 'DarkBlue',figsize = (10,9))
# Out:
# <Axes: title={'center': 'Vote Average by Genre'}, ylabel='genres_split'>

# %%
#we dont need to work with the split data frame so lets make a new one
movies_genres_no_split = movies[column_to_keep]

# %%
movies_genres_no_split.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres  release_year  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller          2015        5562
# 1  Action|Adventure|Science Fiction|Thriller          2015        6185
# 2         Adventure|Science Fiction|Thriller          2015        2480
# 3   Action|Adventure|Science Fiction|Fantasy          2015        5292
# 4                      Action|Crime|Thriller          2015        2947
#
#    vote_average      profit
# 0      6.500000  1363528810
# ...

# %% [markdown]
# 1. The best movies according to vote avg, return high profit and revenue.

# %%
#again lets filter on the vote_count else we will get an unacurate data
movies_high_votes = movies_genres_no_split[movies_genres_no_split['vote_count'] >= 50]

# %%
movies_high_votes.corr(numeric_only = True,method = 'spearman') #check the correlation
# Out:
#               popularity    budget   revenue   runtime  release_year  \
# popularity      1.000000  0.484952  0.588594  0.230214      0.070895
# budget          0.484952  1.000000  0.714733  0.360001     -0.019452
# revenue         0.588594  0.714733  1.000000  0.341469     -0.108974
# runtime         0.230214  0.360001  0.341469  1.000000     -0.131512
# release_year    0.070895 -0.019452 -0.108974 -0.131512      1.000000
# vote_count      0.768888  0.554412  0.682550  0.263164      0.149045
# vote_average    0.189226 -0.044050  0.112201  0.286082     -0.153545
# profit          0.498092  0.334345  0.842278  0.211947     -0.099378
#
#               vote_count  vote_average    profit
# popularity      0.768888      0.189226  0.498092
# budget          0.554412     -0.044050  0.334345
# revenue         0.682550      0.112201  0.842278
# runtime         0.263164      0.286082  0.211947
# release_year    0.149045     -0.153545 -0.099378
# ...

# %%
sns.regplot(x = 'vote_average', y = 'profit' ,data = movies_high_votes,line_kws = {'color':'red'})
# Out:
# <Axes: xlabel='vote_average', ylabel='profit'>

# %%
sns.regplot(x = 'vote_average', y = 'revenue' ,data = movies_high_votes,line_kws = {'color':'red'})
# Out:
# <Axes: xlabel='vote_average', ylabel='revenue'>

# %% [markdown]
# 2. The best movies according to popularity return high profit and revenue.

# %%
movies_high_votes.corr(numeric_only = True,method = 'spearman')
# Out:
#               popularity    budget   revenue   runtime  release_year  \
# popularity      1.000000  0.484952  0.588594  0.230214      0.070895
# budget          0.484952  1.000000  0.714733  0.360001     -0.019452
# revenue         0.588594  0.714733  1.000000  0.341469     -0.108974
# runtime         0.230214  0.360001  0.341469  1.000000     -0.131512
# release_year    0.070895 -0.019452 -0.108974 -0.131512      1.000000
# vote_count      0.768888  0.554412  0.682550  0.263164      0.149045
# vote_average    0.189226 -0.044050  0.112201  0.286082     -0.153545
# profit          0.498092  0.334345  0.842278  0.211947     -0.099378
#
#               vote_count  vote_average    profit
# popularity      0.768888      0.189226  0.498092
# budget          0.554412     -0.044050  0.334345
# revenue         0.682550      0.112201  0.842278
# runtime         0.263164      0.286082  0.211947
# release_year    0.149045     -0.153545 -0.099378
# ...

# %%
sns.regplot(x = 'popularity', y = 'revenue' ,data = movies_high_votes,line_kws = {'color':'red'})
plt.figure(figsize = (15,10))
plt.show()

# %% [markdown]
# 3. Highly budgeted movies return high profit.

# %%
movies_high_votes.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres  release_year  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller          2015        5562
# 1  Action|Adventure|Science Fiction|Thriller          2015        6185
# 2         Adventure|Science Fiction|Thriller          2015        2480
# 3   Action|Adventure|Science Fiction|Fantasy          2015        5292
# 4                      Action|Crime|Thriller          2015        2947
#
#    vote_average      profit
# 0      6.500000  1363528810
# ...

# %%
sns.regplot(x = 'budget', y = 'profit' ,data = movies_high_votes,line_kws = {'color':'red'})
plt.figure(figsize = (15,10))
plt.show()

# %% [markdown]
# 4. Highly budgeted movies have a high popularity.

# %%
sns.regplot(x = 'budget', y = 'popularity' ,data = movies_high_votes,line_kws = {'color':'red'})
plt.figure(figsize = (15,10))
plt.show()

# %% [markdown]
# 5. Look at profit Per Genre Per Year

# %%
movies_genres.head()
# Out:
#    popularity     budget     revenue      original_title  runtime  \
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 1   28.419936  150000000   378436354  Mad Max: Fury Road      120
#
#    release_year  vote_count  vote_average      profit     genres_split
# 0          2015        5562      6.500000  1363528810           Action
# 0          2015        5562      6.500000  1363528810        Adventure
# 0          2015        5562      6.500000  1363528810  Science Fiction
# 0          2015        5562      6.500000  1363528810         Thriller
# 1          2015        6185      7.100000   228436354           Action

# %%
time_genre = movies_genres.groupby(['release_year','genres_split'])[['profit']].mean()

# %%
time_genre
# Out:
#                                       profit
# release_year genres_split
# 1960         Action           6363125.000000
#              Adventure         431000.000000
#              Comedy           5258750.000000
#              Crime                  0.000000
#              Drama            8245619.384615
# ...                                      ...
# 2015         Science Fiction 83321303.523256
#              TV Movie         -150000.000000
#              Thriller        32869106.847953
#              War             54677314.333333
#              Western         72856619.000000
#
# [1049 rows x 1 columns]

# %%
final_genre = pd.pivot_table(time_genre,values = 'profit',index = ['genres_split'],columns = ['release_year'])

# %%
sns.set(rc = {'figure.figsize' : (15,10)})
sns.heatmap(final_genre,cmap = 'YlGnBu',linewidths = .5)
plt.title('Genres by Profit per Year')
plt.show()
